# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns = pd.read_csv("whale_returns.csv")

# %%
# Count nulls
whale_returns.isna().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns.dropna(how = 'all')
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     2015-03-02                        NaN                 NaN
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# ...

# %%
whale_returns.dropna(inplace = True)

# %%
whale_returns.isna().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale_returns.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
# 5  2015-03-09                   0.000582            0.004225
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098
# 5                     0.005843               -0.001652

# %%
whale_returns.set_index(pd.to_datetime(whale_returns['Date'], infer_datetime_format=True), inplace=True)
whale_returns.head(2)
# Out:
#                   Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03  2015-03-03                  -0.001266           -0.004981
# 2015-03-04  2015-03-04                   0.002230            0.003241
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213

# %%
whale_returns.drop(columns=['Date'], inplace=True)
whale_returns.head(2)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns = pd.read_csv("algo_returns.csv")

# %%
# Count nulls
algo_returns.isna().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns.dropna(inplace = True)
algo_returns.isna().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo_returns.head()
# Out:
#           Date    Algo 1    Algo 2
# 6   2014-06-05  0.004062  0.013285
# 7   2014-06-06  0.001857  0.008284
# 8   2014-06-09 -0.005012  0.005668
# 9   2014-06-10  0.004406 -0.000735
# 10  2014-06-11  0.004760 -0.003761

# %%
algo_returns.set_index(pd.to_datetime(algo_returns['Date'], infer_datetime_format=True), inplace=True)
algo_returns.head(2)
# Out:
#                   Date    Algo 1    Algo 2
# Date
# 2014-06-05  2014-06-05  0.004062  0.013285
# 2014-06-06  2014-06-06  0.001857  0.008284

# %%
algo_returns.drop(columns=['Date'], inplace=True)
algo_returns.head(2)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_hist = pd.read_csv("sp500_history.csv")

# %%
# Check Data Types
sp500_hist.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
sp500_hist.head(2)
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97

# %%
sp500_hist["Close"] = sp500_hist["Close"].str.replace("$", " ")
sp500_hist["Close"].head(2)
# Out:
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0     2933.68
# 1     2907.97
# Name: Close, dtype: object

# %%
# Fix Data Types
sp500_hist['Close'] = sp500_hist['Close'].astype(float)

# %%
sp500_hist.head()
# Out:
#         Date    Close
# 0  23-Apr-19  2933.68
# 1  22-Apr-19  2907.97
# 2  18-Apr-19  2905.03
# 3  17-Apr-19  2900.45
# 4  16-Apr-19  2907.06

# %%
# Calculate Daily Returns
sp500_hist.set_index(pd.to_datetime(sp500_hist['Date'], infer_datetime_format=True), inplace=True) 

#Why did I need to place the sort here, in order for it to work?

sp500_hist.head()
# Out:
#                  Date    Close
# Date
# 2019-04-23  23-Apr-19  2933.68
# 2019-04-22  22-Apr-19  2907.97
# 2019-04-18  18-Apr-19  2905.03
# 2019-04-17  17-Apr-19  2900.45
# 2019-04-16  16-Apr-19  2907.06

# %%
sp500_hist.sort_index(inplace=True)
sp500_hist.head(2)
# Out:
#                 Date    Close
# Date
# 2012-10-01  1-Oct-12  1444.49
# 2012-10-02  2-Oct-12  1445.75

# %%
sp500_hist.dropna(inplace=True)
sp500_hist.head(2)
# Out:
#                 Date    Close
# Date
# 2012-10-01  1-Oct-12  1444.49
# 2012-10-02  2-Oct-12  1445.75

# %%
# Drop nulls
sp500_hist.isna().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.  Why is this required?
sp500_hist.rename(columns = {"Close": "SP"},  inplace = True)

# %%
sp500_hist.head(2)
# Out:
#                 Date       SP
# Date
# 2012-10-01  1-Oct-12  1444.49
# 2012-10-02  2-Oct-12  1445.75

# %%
sp500_hist.dtypes
# Out:
# Date     object
# SP      float64
# dtype: object

# %%
sp500 = sp500_hist['SP'].pct_change().dropna()
sp500.head(3)
# Out:
# Date
# 2012-10-02    0.000872
# 2012-10-03    0.003624
# 2012-10-04    0.007174
# Name: SP, dtype: float64

# %%
sp500.sort_index(ascending=True, inplace=True)
sp500.head(2)
# Out:
# Date
# 2012-10-02    0.000872
# 2012-10-03    0.003624
# Name: SP, dtype: float64

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_portf = pd.concat([whale_returns, algo_returns, sp500], axis="columns", join="inner")
combined_portf.head(6)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# 2015-03-10                    -0.012079               -0.009739 -0.001392
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_portf.pct_change().dropna()
combined_portf.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios  #cum = 1+daily return.cumprod()
cumulative_returns = (1 + combined_portf).cumprod()
cumulative_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2        SP
# Date
# 2015-03-03  0.999051  0.995461
# 2015-03-04  1.001464  0.991093
# 2015-03-05  1.005794  0.992278
# ...

# %%
cumulative_returns.sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1094.972254
# PAULSON & CO.INC.               913.708924
# TIGER GLOBAL MANAGEMENT LLC    1197.328870
# BERKSHIRE HATHAWAY INC         1209.482522
# Algo 1                         1448.711349
# Algo 2                         1133.687939
# SP                             1171.865079
# dtype: float64

# %%
# Plot cumulative returns
cumulative_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pd.set_option('display.float_format',  lambda x: '%.3f' % x)

# %%
cumulative_returns.head(2)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                      0.999               0.995
# 2015-03-04                      1.001               0.998
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2015-03-03                        1.000                   0.993   0.998
# 2015-03-04                        0.997                   0.998   0.989
#
#             Algo 2    SP
# Date
# 2015-03-03   0.999 0.995
# 2015-03-04   1.001 0.991

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
boxplot = cumulative_returns.boxplot(figsize = (5,5), rot=90, fontsize='8', grid = False)

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_portf_daily = combined_portf.std() * np.sqrt(1)
combined_portf_daily
# Out:
# SOROS FUND MANAGEMENT LLC     0.008
# PAULSON & CO.INC.             0.007
# TIGER GLOBAL MANAGEMENT LLC   0.011
# BERKSHIRE HATHAWAY INC        0.013
# Algo 1                        0.008
# Algo 2                        0.008
# SP                            0.009
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500
#
# ## Whale_Trades are riskier than SP500 with Avg risk of .00975.

# %%
# Calculate  the daily standard deviation of S&P 500
SP_daily_std = combined_portf['SP'].std() * np.sqrt(1)
SP_daily_std
# Out:
# 0.008553731597758204

# %%
# Determine which portfolios are riskier than the S&P 500
combined_portf.std() * np.sqrt(1)
# Out:
# SOROS FUND MANAGEMENT LLC     0.008
# PAULSON & CO.INC.             0.007
# TIGER GLOBAL MANAGEMENT LLC   0.011
# BERKSHIRE HATHAWAY INC        0.013
# Algo 1                        0.008
# Algo 2                        0.008
# SP                            0.009
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
combined_portf_annual = combined_portf.std() * np.sqrt(252)
combined_portf_annual
# Out:
# SOROS FUND MANAGEMENT LLC     0.125
# PAULSON & CO.INC.             0.111
# TIGER GLOBAL MANAGEMENT LLC   0.173
# BERKSHIRE HATHAWAY INC        0.205
# Algo 1                        0.121
# Algo 2                        0.132
# SP                            0.136
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_portf.rolling(window=21).std()
# Plot the rolling standard deviation
combined_portf.rolling(window=21).std().plot(figsize = (17,6), rot=90, fontsize='8', grid = False)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation_ondaily = combined_portf.corr()
correlation_ondaily
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                        1.000               0.700
# PAULSON & CO.INC.                                0.700               1.000
# TIGER GLOBAL MANAGEMENT LLC                      0.561               0.434
# BERKSHIRE HATHAWAY INC                           0.754               0.546
# Algo 1                                           0.321               0.269
# Algo 2                                           0.827               0.678
# SP                                               0.838               0.670
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                          0.561
# PAULSON & CO.INC.                                  0.434
# TIGER GLOBAL MANAGEMENT LLC                        1.000
# BERKSHIRE HATHAWAY INC                             0.424
# Algo 1                                             0.164
# ...

# %%
# Display de correlation matrix
sns.heatmap(correlation_ondaily, vmin= -1, vmax= 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
#covariance = combined_portf['BERKSHIRE HATHAWAY INC'].cov
covariance = np.cov(whale_returns)
covariance.sum()
# Out:
# 0.10890957059741008

# %%
# Calculate covariance of a single portfolio
covariance = (whale_returns).cov()

# Calculate variance of S&P 500
#variance = np.var(sp500)
variance = combined_portf['SP'].var() 

# Computing beta
whale_ret_beta = covariance / variance

variance
# Out:
# 7.316632424648712e-05

# %%
# Plot beta trend
whale_ret_beta.plot(figsize = (9,5), rot=90, fontsize='8', grid = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_portf.rolling(window=21).std().plot(figsize = (13,5), rot=90, fontsize='8', grid = False)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
correlation = combined_portf.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                        1.000               0.700
# PAULSON & CO.INC.                                0.700               1.000
# TIGER GLOBAL MANAGEMENT LLC                      0.561               0.434
# BERKSHIRE HATHAWAY INC                           0.754               0.546
# Algo 1                                           0.321               0.269
# Algo 2                                           0.827               0.678
# SP                                               0.838               0.670
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                          0.561
# PAULSON & CO.INC.                                  0.434
# TIGER GLOBAL MANAGEMENT LLC                        1.000
# BERKSHIRE HATHAWAY INC                             0.424
# Algo 1                                             0.164
# ...

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_portf.mean()*252) / (combined_portf_annual)
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356
# PAULSON & CO.INC.             -0.484
# TIGER GLOBAL MANAGEMENT LLC   -0.121
# BERKSHIRE HATHAWAY INC         0.622
# Algo 1                         1.379
# Algo 2                         0.501
# SP                             0.648
# dtype: float64

# %%
sharpe_ratios.plot(kind='bar', color='g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ## Algo 2 performed better than Whales portfolio, not SP500.  However, Algo1 is the best selection.  Algo 1 provides higher return and less risk than all.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock AAPL, SPY, NVDA 1 years data calc weighted returnsassuming equal nmbr of shares..Join port together with all portf retrns
#performance and risk to compare to others.  Include corr to discern which stocks are corr. Index by Date compare to Whales and SP500.  
aapl_22 = pd.read_csv("AAPL.csv", index_col= "Date")
aapl_22.head(3)
# Out:
#            AAPL
# Date
# 1/24/22 161.620
# 1/25/22 159.780
# 1/26/22 159.690

# %%
# Reading data from 2nd stock
spy_22 = pd.read_csv("SPY.csv", index_col= "Date")
spy_22.head(3)
# Out:
#             SPY
# Date
# 1/24/22 439.840
# 1/25/22 434.470
# 1/26/22 433.380

# %%
# Reading data from 3rd stock
nvda_22 = pd.read_csv("NVDA.csv", index_col= "Date")
nvda_22.head(3)
# Out:
#            NVDA
# Date
# 1/24/22 233.720
# 1/25/22 223.240
# 1/26/22 227.720

# %%
# Combine all stocks in a single DataFrame
# Reorganize portfolio data by having a column per symbol
combined_asn = pd.concat([aapl_22, spy_22, nvda_22], axis="columns", join="inner")
combined_asn
# Out:
#            AAPL     SPY    NVDA
# Date
# 1/24/22 161.620 439.840 233.720
# 1/25/22 159.780 434.470 223.240
# 1/26/22 159.690 433.380 227.720
# 1/27/22 159.220 431.240 219.440
# 1/28/22 170.330 441.950 228.400
# ...         ...     ...     ...
# 1/13/23 134.760 398.500 168.990
# 1/17/23 135.940 397.770 177.020
# 1/18/23 135.210 391.490 173.770
# 1/19/23 135.270 388.640 167.650
# 1/20/23 137.870 395.880 178.390
#
# [250 rows x 3 columns]

# %%
# Reset Date index
combined_asn.sort_index(ascending = True)
# Out:
#            AAPL     SPY    NVDA
# Date
# 1/10/23 130.730 390.580 159.090
# 1/11/23 133.490 395.520 160.010
# 1/12/23 133.410 396.960 165.110
# 1/13/23 134.760 398.500 168.990
# 1/17/23 135.940 397.770 177.020
# ...         ...     ...     ...
# 9/30/22 138.200 357.180 121.390
# 9/6/22  154.530 390.760 134.650
# 9/7/22  155.960 397.780 137.140
# 9/8/22  154.460 400.380 139.900
# 9/9/22  157.370 406.600 143.870
#
# [250 rows x 3 columns]

# %%
# Calculate daily returns
combined_asn = combined_asn.pct_change().dropna()
# Drop NAs

# Display sample data
combined_asn.sample(5)
# Out:
#           AAPL    SPY   NVDA
# Date
# 3/8/22  -0.012 -0.008  0.008
# 8/26/22 -0.038 -0.034 -0.092
# 4/13/22  0.016  0.011  0.033
# 8/24/22  0.002  0.003  0.002
# 7/12/22  0.007 -0.009 -0.005

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
weighted_return = combined_asn.dot(weights)
# Display sample data
weighted_return.sample(4)
# Out:
# Date
# 4/4/22      0.019
# 9/21/22    -0.010
# 3/22/22     0.008
# 11/22/22    0.025
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

portfolio_wreturns = pd.concat([combined_asn, weighted_return], axis="columns", join="inner").dropna()
portfolio_wreturns
# Out:
#           AAPL    SPY   NVDA      0
# Date
# 1/25/22 -0.011 -0.012 -0.045 -0.023
# 1/26/22 -0.001 -0.003  0.020  0.006
# 1/27/22 -0.003 -0.005 -0.036 -0.015
# 1/28/22  0.070  0.025  0.041  0.045
# 1/31/22  0.026  0.018  0.072  0.039
# ...        ...    ...    ...    ...
# 1/13/23  0.010  0.004  0.023  0.012
# 1/17/23  0.009 -0.002  0.048  0.018
# 1/18/23 -0.005 -0.016 -0.018 -0.013
# 1/19/23  0.000 -0.007 -0.035 -0.014
# 1/20/23  0.019  0.019  0.064  0.034
#
# [249 rows x 4 columns]

# %%
portfolio_wreturns = portfolio_wreturns.dropna().copy()

# %%
portfolio_wreturns.dtypes
# Out:
# AAPL    float64
# SPY     float64
# NVDA    float64
# 0       float64
# dtype: object

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
##sp500_hist.rename(columns = {"Close": "SP_atClose"}, inplace = True)
portfolio_wreturns.rename(columns = {0:"W_Returns"}, inplace=True)
portfolio_wreturns.head(2)
# Out:
#           AAPL    SPY   NVDA  W_Returns
# Date
# 1/25/22 -0.011 -0.012 -0.045     -0.023
# 1/26/22 -0.001 -0.003  0.020      0.006

# %%
portfolio_wreturns.isnull().sum()
# Out:
# AAPL         0
# SPY          0
# NVDA         0
# W_Returns    0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
combined_std_annual = combined_asn.std() * np.sqrt(252)
combined_std_annual
# Out:
# AAPL   0.359
# SPY    0.244
# NVDA   0.637
# dtype: float64

# %%
combined_std_annul_port = portfolio_wreturns.std() * np.sqrt(252)
combined_std_annul_port
# Out:
# AAPL        0.359
# SPY         0.244
# NVDA        0.637
# W_Returns   0.388
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_asn.rolling(window=21).std()
# Plot rolling standard deviation
combined_asn.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_asn = combined_asn.corr()

sns.heatmap(correlation_asn, vmin= -1, vmax= 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
## Showcase beta vs. correlation by plotting a scatterplot using the seaborn library and fitting a regression line
#sns.lmplot(x='SP500', y='MSFT', data=daily_returns, aspect=1.5, fit_reg=True)

covariance2 = combined_asn.cov()

covariance2
# Out:
#       AAPL   SPY  NVDA
# AAPL 0.001 0.000 0.001
# SPY  0.000 0.000 0.001
# NVDA 0.001 0.001 0.002

# %%
variance2 = combined_portf['SP'].var()
variance2
# Out:
# 7.316632424648712e-05

# %%
asn_beta = covariance2 / variance2
asn_beta
# Out:
#       AAPL   SPY   NVDA
# AAPL 7.005 4.190  9.422
# SPY  4.190 3.225  7.044
# NVDA 9.422 7.044 22.040

# %%
asn_beta
# Out:
#       AAPL   SPY   NVDA
# AAPL 7.005 4.190  9.422
# SPY  4.190 3.225  7.044
# NVDA 9.422 7.044 22.040

# %%
## Showcase beta vs. correlation by plotting a scatterplot using the seaborn library and fitting a regression line
#sns.lmplot(x='SP500', y='asn_beta', data=combined_asn, aspect=1.5, fit_reg=True)
rolling_combined_asn_A = combined_asn['AAPL'].rolling(window=60).cov(combined_portf['SP'])
rolling_combined_asn_S = combined_asn['SPY'].rolling(window=60).cov(combined_portf['SP'])
rolling_combined_asn_N = combined_asn['NVDA'].rolling(window=60).cov(combined_portf['SP'])

rolling_var = combined_portf['SP'].rolling(window=60).var()

A_beta = rolling_combined_asn_A/rolling_var
S_beta = rolling_combined_asn_S/rolling_var
N_beta = rolling_combined_asn_N/rolling_var

# %%
ax = rolling_combined_asn_A.plot(x ='ax', figsize=(10, 10), title='Rolling 60-Day Beta AAPL, SPY, NVDA')
rolling_combined_asn_S.plot(ax=ax)
rolling_combined_asn_N.plot(ax=ax)
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta AAPL, SPY, NVDA'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios2 = (combined_asn.mean()*252)/ (combined_std_annual)
sharpe_ratios
sharpe_ratios2
# Out:
# AAPL   -0.269
# SPY    -0.315
# NVDA   -0.112
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios2.plot(kind='bar', color='g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
# ## My portfolio was to low risk but this is my perception with only pulling 12 month data.

# %%
cumulative_returns = (1 + combined_asn).cumprod()
cumulative_returns.head()
# Out:
#          AAPL   SPY  NVDA
# Date
# 1/25/22 0.989 0.988 0.955
# 1/26/22 0.988 0.985 0.974
# 1/27/22 0.985 0.980 0.939
# 1/28/22 1.054 1.005 0.977
# 1/31/22 1.081 1.023 1.048
